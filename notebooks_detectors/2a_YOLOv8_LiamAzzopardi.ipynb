# %% [markdown]
# ## YOLOv8-n Training

# %%
from ultralytics import YOLO
from ultralytics.utils import SETTINGS

# Enable TensorBoard logging
SETTINGS['tensorboard'] = True
print(f"TensorBoard enabled: {SETTINGS['tensorboard']}")

# loading pretrained YOLOv8-n model
model = YOLO('yolov8n.pt')

# training
results = model.train(
    data='data.yaml',
    epochs=100,
    imgsz=640,
    batch=8,
    patience=25,
    save=True,
    device='0',
    workers=8,
    project='traffic_signs',
    name='yolov8_final_run',
    exist_ok=True,
    optimizer='auto',
    verbose=True,
    seed=42,
    deterministic=True,
    plots=True,
    save_period=1,
    warmup_epochs=3.0,
    cos_lr=True
)

print("Training Complete")
# Out:
# TensorBoard enabled: True
# New https://pypi.org/project/ultralytics/8.4.7 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.253  Python-3.10.19 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1080, 8192MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8_final_run, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=25, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=traffic_signs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\Advanced-CV-Assignment\traffic_signs\yolov8_final_run, save_frames=False, save_json=False, save_period=1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# TensorBoard: Start with 'tensorboard --logdir D:\Advanced-CV-Assignment\traffic_signs\yolov8_final_run', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752482  ultralytics.nn.modules.head.Detect           [6, [64, 128, 256]]
# Model summary: 129 layers, 3,012,018 parameters, 3,012,002 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 5.09.9 ms, read: 82.136.6 MB/s, size: 2210.4 KB)
# train: Scanning D:\Advanced-CV-Assignment\YOLO_COCO\labels\train.cache... 488 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 488/488  0.0s
# WARNING val: Slow image access detected (ping: 36.862.6 ms, read: 61.518.1 MB/s, size: 2109.4 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning D:\Advanced-CV-Assignment\YOLO_COCO\labels\val.cache... 93 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 93/93  0.0s
# Plotting labels to D:\Advanced-CV-Assignment\traffic_signs\yolov8_final_run\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# C:\Users\vti15\AppData\Roaming\Python\Python310\site-packages\torch\jit\_trace.py:685: UserWarning: The input to trace is already a ScriptModule, tracing it is a no-op. Returning the object as is.
#   warnings.warn(
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to D:\Advanced-CV-Assignment\traffic_signs\yolov8_final_run
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      1.14G     0.8647      3.242      1.137         20        640: 100% ━━━━━━━━━━━━ 61/61 4.0it/s 15.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.1s0.3s
#                    all         93        110       0.62      0.272      0.407      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      1.46G     0.8523      2.293      1.084         11        640: 100% ━━━━━━━━━━━━ 61/61 5.1it/s 11.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all         93        110      0.468      0.507      0.507      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      1.48G     0.9201      2.108      1.114         15        640: 100% ━━━━━━━━━━━━ 61/61 3.8it/s 16.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.5it/s 1.7s0.3s
#                    all         93        110      0.544      0.556      0.568      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100       1.5G     0.8592      1.855        1.1         26        640: 100% ━━━━━━━━━━━━ 61/61 3.5it/s 17.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.6it/s 1.3s0.3s
#                    all         93        110      0.558      0.545      0.511      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100       1.5G     0.8857      1.758      1.113         17        640: 100% ━━━━━━━━━━━━ 61/61 4.1it/s 15.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.4it/s 2.5s0.6s
#                    all         93        110      0.585      0.617      0.615       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100       1.5G     0.8902      1.604      1.096         21        640: 100% ━━━━━━━━━━━━ 61/61 3.9it/s 15.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.6it/s 1.7s0.4s
#                    all         93        110      0.693      0.596      0.645      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100       1.5G     0.8535      1.502      1.073          9        640: 100% ━━━━━━━━━━━━ 61/61 3.4it/s 17.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s0.2s
#                    all         93        110      0.679      0.676      0.685      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      1.51G     0.8431      1.459      1.076         16        640: 100% ━━━━━━━━━━━━ 61/61 3.5it/s 17.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s0.2s
#                    all         93        110      0.823       0.63      0.694      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      1.52G     0.8411      1.355      1.065         20        640: 100% ━━━━━━━━━━━━ 61/61 3.8it/s 16.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all         93        110      0.702      0.646      0.664      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      1.54G     0.8341       1.31       1.08         17        640: 100% ━━━━━━━━━━━━ 61/61 3.5it/s 17.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all         93        110      0.801       0.62      0.713      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      1.56G     0.8297      1.193      1.084         15        640: 100% ━━━━━━━━━━━━ 61/61 3.6it/s 17.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all         93        110      0.802      0.706      0.746      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      1.57G     0.8433      1.178      1.077         13        640: 100% ━━━━━━━━━━━━ 61/61 3.8it/s 16.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.1it/s 1.5s0.3s
#                    all         93        110       0.84      0.681      0.733      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      1.59G     0.7985      1.123      1.062         19        640: 100% ━━━━━━━━━━━━ 61/61 3.6it/s 17.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.3it/s 1.1s0.2s
#                    all         93        110      0.899      0.713      0.779      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      1.61G     0.7905      1.059       1.06         22        640: 100% ━━━━━━━━━━━━ 61/61 3.7it/s 16.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.0it/s 1.0s0.2s
#                    all         93        110      0.875      0.711      0.769      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      1.61G     0.7978      1.068      1.061         15        640: 100% ━━━━━━━━━━━━ 61/61 4.6it/s 13.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.3it/s 1.8s0.4s
#                    all         93        110      0.892      0.672        0.8      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      1.61G     0.8074     0.9927       1.07         15        640: 100% ━━━━━━━━━━━━ 61/61 3.8it/s 16.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.5it/s 1.7s0.4s
#                    all         93        110      0.785        0.7      0.761      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      1.61G     0.7737     0.9802      1.046         23        640: 100% ━━━━━━━━━━━━ 61/61 4.0it/s 15.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.3it/s 1.8s0.4s
#                    all         93        110      0.808      0.674      0.748      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      1.61G     0.7647     0.9291      1.053         17        640: 100% ━━━━━━━━━━━━ 61/61 3.8it/s 16.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.3it/s 1.8s0.4s
#                    all         93        110      0.831      0.775       0.77      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      1.61G     0.7513     0.9421      1.034         18        640: 100% ━━━━━━━━━━━━ 61/61 4.2it/s 14.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.0s0.4s
#                    all         93        110      0.799      0.729       0.73      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      1.61G     0.8006     0.9447       1.06         19        640: 100% ━━━━━━━━━━━━ 61/61 3.1it/s 19.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.4it/s 2.5s0.5s
#                    all         93        110      0.864      0.746       0.79       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      1.61G     0.7667     0.8875      1.034         16        640: 100% ━━━━━━━━━━━━ 61/61 3.5it/s 17.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.3it/s 2.6s0.6s
#                    all         93        110      0.853       0.76      0.799      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      1.61G     0.7588     0.8577      1.037         23        640: 100% ━━━━━━━━━━━━ 61/61 3.6it/s 16.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.1s0.4s
#                    all         93        110      0.793       0.78      0.783      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      1.61G     0.7738     0.8458      1.032         20        640: 100% ━━━━━━━━━━━━ 61/61 3.9it/s 15.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.1it/s 1.9s0.4s
#                    all         93        110      0.839      0.755       0.77      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      1.61G     0.7446     0.8148       1.03         18        640: 100% ━━━━━━━━━━━━ 61/61 4.0it/s 15.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s0.5s
#                    all         93        110      0.822      0.773        0.8      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      1.62G     0.7398        0.8      1.037         21        640: 100% ━━━━━━━━━━━━ 61/61 3.7it/s 16.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.1it/s 1.9s0.4s
#                    all         93        110      0.833      0.715      0.729      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      1.62G     0.7531     0.7808       1.05         15        640: 100% ━━━━━━━━━━━━ 61/61 3.5it/s 17.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.4s0.7s
#                    all         93        110      0.854      0.654       0.73       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      1.62G     0.7454      0.803      1.032         18        640: 100% ━━━━━━━━━━━━ 61/61 3.2it/s 19.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.0it/s 2.0s0.4s
#                    all         93        110      0.802      0.755      0.771      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      1.62G     0.7298     0.7521      1.023         20        640: 100% ━━━━━━━━━━━━ 61/61 3.4it/s 17.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.4s
#                    all         93        110      0.879      0.763       0.79      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      1.62G     0.6963      0.715      1.011         19        640: 100% ━━━━━━━━━━━━ 61/61 4.0it/s 15.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s0.5s
#                    all         93        110      0.872      0.665      0.755      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      1.62G     0.7056     0.7115      1.022         14        640: 100% ━━━━━━━━━━━━ 61/61 3.5it/s 17.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.6it/s 1.7s0.3s
#                    all         93        110      0.923      0.768      0.828      0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      1.62G     0.7103     0.7349      1.028         21        640: 100% ━━━━━━━━━━━━ 61/61 4.0it/s 15.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.0it/s 2.0s0.4s
#                    all         93        110      0.898      0.735      0.822      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      1.62G     0.7449     0.7389      1.021         30        640: 100% ━━━━━━━━━━━━ 61/61 4.0it/s 15.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.0it/s 2.0s0.4s
#                    all         93        110      0.889      0.757      0.787      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      1.62G     0.7189     0.6681      1.019         18        640: 100% ━━━━━━━━━━━━ 61/61 4.0it/s 15.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.0s0.4s
#                    all         93        110      0.809      0.756      0.801      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      1
/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.1it/s 1.9s0.4s
#                    all         93        110      0.858        0.8      0.811      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      1.63G     0.5215     0.4178     0.9373         12        640: 100% ━━━━━━━━━━━━ 61/61 4.5it/s 13.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.4it/s 1.8s0.3s
#                    all         93        110      0.895      0.776      0.816      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      1.63G     0.5004     0.4145     0.9188         18        640: 100% ━━━━━━━━━━━━ 61/61 4.6it/s 13.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all         93        110      0.901      0.771      0.816      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      1.63G     0.4903     0.4029     0.9231         16        640: 100% ━━━━━━━━━━━━ 61/61 4.6it/s 13.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.7it/s 1.6s0.3s
#                    all         93        110      0.913      0.756      0.817      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      1.63G     0.4898     0.3959      0.924         24        640: 100% ━━━━━━━━━━━━ 61/61 4.7it/s 12.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.4it/s 1.8s0.3s
#                    all         93        110      0.906      0.755      0.818       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      1.63G     0.4835     0.3978     0.9094         17        640: 100% ━━━━━━━━━━━━ 61/61 4.3it/s 14.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all         93        110      0.886      0.764      0.817       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      1.63G     0.4885     0.3934     0.9138         19        640: 100% ━━━━━━━━━━━━ 61/61 4.1it/s 14.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.8it/s 1.6s0.3s
#                    all         93        110      0.905      0.727      0.792      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      1.63G     0.4826     0.4031     0.9224         17        640: 100% ━━━━━━━━━━━━ 61/61 4.4it/s 13.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.3it/s 1.8s0.3s
#                    all         93        110      0.869      0.778      0.814      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      1.63G     0.4735     0.3802     0.9182         35        640: 100% ━━━━━━━━━━━━ 61/61 3.5it/s 17.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s0.4s
#                    all         93        110      0.906      0.741      0.806      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      1.63G     0.4806     0.3866     0.9216         21        640: 100% ━━━━━━━━━━━━ 61/61 3.5it/s 17.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.9it/s 1.0s0.2s
#                    all         93        110       0.89      0.749      0.804      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      1.63G     0.4885     0.3902      0.916         20        640: 100% ━━━━━━━━━━━━ 61/61 4.4it/s 13.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.5it/s 1.7s0.4s
#                    all         93        110      0.901      0.738      0.799      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      1.63G     0.4644     0.3705     0.9072         24        640: 100% ━━━━━━━━━━━━ 61/61 4.8it/s 12.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.5it/s 1.7s0.3s
#                    all         93        110      0.894      0.734      0.784      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      1.63G     0.5015     0.4066      0.933         19        640: 100% ━━━━━━━━━━━━ 61/61 4.9it/s 12.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.3it/s 1.8s0.4s
#                    all         93        110      0.848      0.768      0.787      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      1.63G     0.4789     0.3932     0.9194         20        640: 100% ━━━━━━━━━━━━ 61/61 4.7it/s 12.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.6it/s 1.7s0.3s
#                    all         93        110      0.872      0.757      0.782      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      1.63G     0.4783     0.3839     0.9179         17        640: 100% ━━━━━━━━━━━━ 61/61 4.5it/s 13.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.5it/s 1.7s0.4s
#                    all         93        110      0.871      0.755       0.78      0.617
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      1.63G     0.4031     0.3106     0.8491          9        640: 100% ━━━━━━━━━━━━ 61/61 5.4it/s 11.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s0.2s
#                    all         93        110      0.858      0.752      0.774      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      1.63G     0.3975     0.3022     0.8392          9        640: 100% ━━━━━━━━━━━━ 61/61 3.6it/s 17.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.7it/s 1.6s0.4s
#                    all         93        110      0.855      0.757      0.777      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      1.63G     0.3922     0.2955     0.8392         11        640: 100% ━━━━━━━━━━━━ 61/61 3.8it/s 16.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all         93        110      0.878      0.737      0.781      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      1.63G     0.3824     0.2926     0.8376         10        640: 100% ━━━━━━━━━━━━ 61/61 3.7it/s 16.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.1s0.2s
#                    all         93        110      0.869      0.741      0.782      0.616
# EarlyStopping: Training stopped early as no improvement observed in last 25 epochs. Best results observed at epoch 69, best model saved as best.pt.
# To update EarlyStopping(patience=25) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 94 epochs completed in 0.529 hours.
# Optimizer stripped from D:\Advanced-CV-Assignment\traffic_signs\yolov8_final_run\weights\last.pt, 6.2MB
# Optimizer stripped from D:\Advanced-CV-Assignment\traffic_signs\yolov8_final_run\weights\best.pt, 6.2MB
#
# Validating D:\Advanced-CV-Assignment\traffic_signs\yolov8_final_run\weights\best.pt...
# Ultralytics 8.3.253  Python-3.10.19 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1080, 8192MiB)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.4it/s 2.5s0.4ss
#                    all         93        110      0.884      0.787      0.816       0.64
# Blind-Spot Mirror (Convex)         13         13      0.824      0.615      0.681      0.445
#     No Entry (One Way)         27         28      0.959      0.846      0.882      0.737
# No Through Road (T-Sign)         12         12      0.807      0.833      0.753       0.55
#    Pedestrian Crossing         19         21      0.869      0.714       0.74      0.545
#       Roundabout Ahead         19         20      0.934      0.711      0.847      0.669
#                   Stop         16         16      0.913          1      0.995      0.894
# Speed: 0.3ms preprocess, 10.3ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to D:\Advanced-CV-Assignment\traffic_signs\yolov8_final_run
# Training Complete

# %% [markdown]
# ## YOLOv8 Evaluation

# %%
from ultralytics import YOLO
# load best model from training for evaluation
best_model = YOLO('traffic_signs/yolov8_run1/weights/best.pt')


# test on Training Set

print("Evaluating on training set")
train_metrics = best_model.val(
    data='data.yaml',
    split='train',
    batch=8,
    device='0',
    plots=True,
    save_json=True,
    project='traffic_signs',
    name='eval_train'
)

# test on Validation Set
print("Evaluating on validation set")
val_metrics = best_model.val(
    data='data.yaml',
    split='val',
    batch=8,
    device='0',
    plots=True,
    save_json=True,
    project='traffic_signs',
    name='eval_val'
)

# test on Test Set
print("Evaluating on test set")
test_metrics = best_model.val(
    data='data.yaml',
    split='test',
    batch=8,
    device='0',
    plots=True,
    save_json=True,
    project='traffic_signs',
    name='eval_test'
)

# print summary of all results

print("EVALUATION SUMMARY")

print("\nTRAINING SET:")
print(f"  mAP50: {train_metrics.box.map50:.4f}")
print(f"  mAP50-95: {train_metrics.box.map:.4f}")

print("\nVALIDATION SET:")
print(f"  mAP50: {val_metrics.box.map50:.4f}")
print(f"  mAP50-95: {val_metrics.box.map:.4f}")

print("\nTEST SET:")
print(f"  mAP50: {test_metrics.box.map50:.4f}")
print(f"  mAP50-95: {test_metrics.box.map:.4f}")
# Out:
# Evaluating on training set
# Ultralytics 8.3.253  Python-3.10.19 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1080, 8192MiB)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 6.79.2 ms, read: 78.919.2 MB/s, size: 2054.4 KB)
# val: Scanning D:\Advanced-CV-Assignment\YOLO_COCO\labels\train.cache... 488 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 488/488  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 61/61 2.7it/s 22.5s0.2ss
#                    all        488        571      0.979      0.945      0.973      0.876
# Blind-Spot Mirror (Convex)         82         83      0.973       0.94      0.974      0.897
#     No Entry (One Way)        128        138      0.992      0.944      0.978      0.898
# No Through Road (T-Sign)         63         63      0.978      0.968      0.985      0.914
#    Pedestrian Crossing         92        103      0.978      0.882      0.927      0.808
#       Roundabout Ahead         68         74      0.957      0.946      0.979      0.819
#                   Stop        108        110      0.993      0.991      0.995      0.923
# Speed: 1.6ms preprocess, 4.1ms inference, 0.0ms loss, 2.9ms postprocess per image
# Saving D:\Advanced-CV-Assignment\traffic_signs\eval_train2\predictions.json...
# Results saved to D:\Advanced-CV-Assignment\traffic_signs\eval_train2
# Evaluating on validation set
# Ultralytics 8.3.253  Python-3.10.19 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1080, 8192MiB)
# val: Fast image access  (ping: 2.33.8 ms, read: 101.416.5 MB/s, size: 2469.4 KB)
# val: Scanning D:\Advanced-CV-Assignment\YOLO_COCO\labels\val.cache... 93 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 93/93  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 1.4s/it 16.9s0.2s
#                    all         93        110      0.884      0.786      0.819      0.641
# Blind-Spot Mirror (Convex)         13         13      0.825      0.615      0.678      0.444
#     No Entry (One Way)         27         28      0.959      0.845      0.881      0.735
# No Through Road (T-Sign)         12         12      0.805      0.833      0.768      0.562
#    Pedestrian Crossing         19         21       0.87      0.714      0.746      0.549
#       Roundabout Ahead         19         20      0.934       0.71      0.847      0.668
#                   Stop         16         16      0.914          1      0.995      0.888
# Speed: 2.5ms preprocess, 9.5ms inference, 0.0ms loss, 3.5ms postprocess per image
# Saving D:\Advanced-CV-Assignment\traffic_signs\eval_val2\predictions.json...
# Results saved to D:\Advanced-CV-Assignment\traffic_signs\eval_val2
# Evaluating on test set
# Ultralytics 8.3.253  Python-3.10.19 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1080, 8192MiB)
# val: Fast image access  (ping: 4.15.5 ms, read: 91.222.5 MB/s, size: 1783.5 KB)
# val: Scanning D:\Advanced-CV-Assignment\YOLO_COCO\labels\test.cache... 122 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 122/122  0.0s
# val: D:\Advanced-CV-Assignment\YOLO_COCO\images\test\1989d2bf-front.jpg: corrupt JPEG restored and saved
# val: D:\Advanced-CV-Assignment\YOLO_COCO\images\test\313f61a3-front.jpg: corrupt JPEG restored and saved
# val: D:\Advanced-CV-Assignment\YOLO_COCO\images\test\32be709f-side.jpg: corrupt JPEG restored and saved
# val: D:\Advanced-CV-Assignment\YOLO_COCO\images\test\3ec82dec-back.jpg: corrupt JPEG restored and saved
# val: D:\Advanced-CV-Assignment\YOLO_COCO\images\test\4802289d-side.jpg: corrupt JPEG restored and saved
# val: D:\Advanced-CV-Assignment\YOLO_COCO\images\test\646a4174-side.jpg: corrupt JPEG restored and saved
# val: D:\Advanced-CV-Assignment\YOLO_COCO\images\test\9fcc7003-front.jpg: corrupt JPEG restored and saved
# val: D:\Advanced-CV-Assignment\YOLO_COCO\images\test\bd276beb-back.jpg: corrupt JPEG restored and saved
# val: D:\Advanced-CV-Assignment\YOLO_COCO\images\test\ce78c9cf-front.jpg: corrupt JPEG restored and saved
# val: D:\Advanced-CV-Assignment\YOLO_COCO\images\test\d64a92d8-side.jpg: corrupt JPEG restored and saved
# val: D:\Advanced-CV-Assignment\YOLO_COCO\images\test\dde100ed-side.jpg: corrupt JPEG restored and saved
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.0it/s 15.9s0.2s
#                    all        122        149      0.922      0.772      0.855      0.723
# Blind-Spot Mirror (Convex)         21         21      0.966       0.81      0.893      0.801
#     No Entry (One Way)         24         26      0.915      0.885      0.901      0.745
# No Through Road (T-Sign)         14         14       0.98      0.857      0.912      0.769
#    Pedestrian Crossing         30         34      0.878      0.638      0.816       0.67
#       Roundabout Ahead         19         23      0.861      0.539      0.682      0.517
#                   Stop         31         31      0.929      0.903      0.928      0.832
# Speed: 2.4ms preprocess, 5.5ms inference, 0.0ms loss, 4.5ms postprocess per image
# Saving D:\Advanced-CV-Assignment\traffic_signs\eval_test2\predictions.json...
# Results saved to D:\Advanced-CV-Assignment\traffic_signs\eval_test2
# EVALUATION SUMMARY
#
# TRAINING SET:
#   mAP50: 0.9728
#   mAP50-95: 0.8765
#
# VALIDATION SET:
#   mAP50: 0.8191
#   mAP50-95: 0.6409
#
# TEST SET:
#   mAP50: 0.8552
#   mAP50-95: 0.7225
